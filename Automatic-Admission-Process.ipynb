# %% [markdown]
# # Automatic-Admission-Process
# # NAME : DIVY D. CHAVDA

# %% [markdown]
# # Introduced My Program ::-
#
# A government wants to automate the admission process in all engineering colleges. A
# government collected all relevant data and store it in CSV file.
#
# First File College_details.csv columns like CollegeCode,No of seat for each branch,Rank given by government.
#
# Second file is studentdetails.csv which has information about the students result and their
# enrolment key. columns like student enrolment key and 5 subject marks.
#
# Third file has choice_filling.csv which has student admission choice details columns like enrolment
# key and 10 preferable CollegeID-Branch code in which he/she likes to take admission.
#
# 1) First Generate the college_details.csv and studentdetails.csv file. Generate the atleast 100
#    colleges and 10000 students data.
#
# 2) Give rank to the students so that admission process will be performed in proper sequence.
#
# 3) ask user to give atleast 3 preferable branch code in which they want to take admission and generate the data
#    based on the branch choice entered by student and store in the choice_filling.csv file.
#
# 4) First generate the data for 500 students and try to give them admission in their preferable college and branch.
#
# 5) Every day, the admission process of 500 students is carried out by the system.
#
# 6) At the end of first day of admission process, generate day1_college_status.csv file, which has details like number
#    of vacant seats, branch wise, in all the colleges that will available for admission process on day 2.
#
# 7) Run this System until entire admission process get over.
#
# 8) So, Finally Generate the report which shows the collegewise-branchwise first and last enrolment number which can be helpful
#    to next year students. And Also publish rank to each branch which is highly preferred by student for current year admission.
#
# # Note ::-
#          if i use more amount of data like 10000 students and 100 colleges so more process time will be taken by system
#          thats why i am using less amount of data like 50 student and 10 colleges
#          Also in my program user do not need to create any CSV file my program will automatically generate it

# %%
#Import necessary libraries.
import csv # importing csv module
import numpy as np # Load the numpy libraries with alias 'np' 
import pandas as pd # Load the Pandas libraries with alias 'pd' 
import random # Load the random libraries For generating random data
import os # Find out your current working directory
from pathlib import Path
import operator # importing operator module

# %% [markdown]
# # Question - 1
#
# Q-1 - Generate the college_details.csv file. Generate the atleast 100 colleges.(use 10 colleges instead 100 college)
#
# Answer ->
#
#           in this first question declare the so many list to store the data like CollegeCode,CSE Branch seat, IT Branch
#           seat, ME Branch seat, EE Branch seat, EC Branch seat, IC Branch seat, CH Branch seat, ICT Branch seat, and
#           last Rank list of the college. In the first list store 10 records of CollegeCode randomly generate number and
#           it combine with declare variable value 'C' and the store 10 records of CSE,IT,ME,EE,EC,IC,CH,ICT in this list
#           insert value using randomly choice the value in one declarable list and in the Rank list insert the value
#           randomly choice the value in between 1 to 10 and value does not repeat.
#
#           use the zip function to combine multiple list into singal list
#
#           then check the CSV file College_details already exist or not if it is exist then remove it and create the
#           new College_details.csv file and insert data of the combine list
#
#           here also check copy_of_College_details.csv file exist or not if it is exist then remove it and create the new
#           copy_of_College_details.csv file and insert data of the combine list
#           the main moto is create this copy_of_College_details.csv file because when program is execute successfully and
#           find the total number of seat in the college in branch wise before the program will be start to execute
#           so College_details.csv give this details and use copy_of_College_details.csv for appropriate operation
#
#           and finally print the College_details.csv file

# %%
CollegeCode=list([]) #This List is used to store the CollegeCode
CSE=list([])  #This List is used to store the CSE Branch Seat
IT=list([])  #This List is used to store the IT Branch Seat
ME=list([])  #This List is used to store the ME Branch Seat
EE=list([])  #This List is used to store the EE Branch Seat
EC=list([])  #This List is used to store the EC Branch Seat
IC=list([])  #This List is used to store the IC Branch Seat
CH=list([])  #This List is used to store the CH Branch Seat
ICT=list([])  #This List is used to store the ICT Branch Seat
Rank=list([])  #This List is used to store the Rank of colleges
clg = 'C'  #variable clg declare with 'C' will be used as combine with CollegeCode
for i in range(1,11):  #For Loop to insert 10 records from in CollegeCode list
    s = ''.join(['{0:04}'.format(i)])  #in variable s assign 0001,0002 base on i 
    ans = clg+s  #variable ans combine varible clg and variable s
    CollegeCode.append(ans)  #variable ans value append in the CollegeCode list

for i in range(0,10):  #For Loop to insert 10 records from in CSE list
    foo = [0,60,120,180]  #list foo declare with 0,60,120,180 value
    CSE.append(random.choice(foo)) #Random Choice value from the foo-list and append in the CSE list
    
for i in range(0,10):  #For Loop to insert 10 records from in IT list
    foo = [0,60,120,180]  #list foo declare with 0,60,120,180 value
    IT.append(random.choice(foo))  #Random Choice value from the foo-list and append in the IT list
    
for i in range(0,10):  #For Loop to insert 10 records from in ME list
    foo = [0,60,120,180]  #list foo declare with 0,60,120,180 value
    ME.append(random.choice(foo))  #Random Choice value from the foo-list and append in the ME list
    
for i in range(0,10):  #For Loop to insert 10 records from in EE list
    foo = [0,60,120,180]  #list foo declare with 0,60,120,180 value
    EE.append(random.choice(foo))  #Random Choice value from the foo-list and append in the EE list
    
for i in range(0,10):  #For Loop to insert 10 records from in EC list
    foo = [0,60,120,180]  #list foo declare with 0,60,120,180 value
    EC.append(random.choice(foo))  #Random Choice value from the foo-list and append in the EC list
    
for i in range(0,10):  #For Loop to insert 10 records from in IC list
    foo = [0,60,120,180]  #list foo declare with 0,60,120,180 value
    IC.append(random.choice(foo))  #Random Choice value from the foo-list and append in the IC list
    
for i in range(0,10):  #For Loop to insert 10 records from in CH list
    foo = [0,60,120,180]  #list foo declare with 0,60,120,180 value
    CH.append(random.choice(foo))  #Random Choice value from the foo-list and append in the CH list
    
for i in range(0,10):  #For Loop to insert 10 records from in ICT list
    foo = [0,60,120,180]  #list foo declare with 0,60,120,180 value
    ICT.append(random.choice(foo))  #Random Choice value from the foo-list and append in the ICT list
    
Rank = random.sample(range(1, 11), 10)  #insert value into Rank list randomly choice 1-to-10 value and value should not repeat

rows = zip(CollegeCode,CSE,IT,ME,EE,EC,IC,CH,ICT,Rank)  #zip combine multiple list into one list so all list combine into 'rows'

my_file = Path("College_details.csv")  #check the College_details.csv file path are avilable or not
if my_file.is_file():  #check file is exist or not
    os.remove('College_details.csv')  #if file is exist so remove it
        
with open('College_details.csv','w',newline="\n") as file:  #Open/Create file with 'w' mode.
    writer=csv.writer(file, delimiter=',')  #Declaring writer to write data into College_details.csv file.
    writer.writerow(["CollegeCode", "CSE", "IT", "ME", "EE", "EC", "IC", "CH", "ICT", "Rank"])  #write first row in College_details.csv.
    for row in rows:  #There are multiple rows in 'rows' list so, each row will be extracted and stored in 'row'
        writer.writerow(row)  #writerow function will write/add new row in College_details.csv
        
rows1 = zip(CollegeCode,CSE,IT,ME,EE,EC,IC,CH,ICT,Rank)  #zip combine multiple list into one list so all list combine into 'rows1'

my_file1 = Path("copy_of_College_details.csv")  #check the copy_of_College_details.csv file path are avilable or not
if my_file1.is_file():  #check file is exist or not
    os.remove('copy_of_College_details.csv')  #if file is exist so remove it
    
with open('copy_of_College_details.csv','w',newline="\n") as file:   #Open/Create file with 'w' mode.
    writer=csv.writer(file, delimiter=',')  #Declaring writer to write data into copy_of_College_details.csv file.
    writer.writerow(["CollegeCode", "CSE", "IT", "ME", "EE", "EC", "IC", "CH", "ICT", "Rank"])  #write first row in copy_of_College_details.csv
    for row in rows1:  #There are multiple rows in 'rows1' list so, each row will be extracted and stored in 'row'
        writer.writerow(row)  #writerow function will write/add new row in copy_of_College_details.csv.
        
college = pd.read_csv("College_details.csv")  #Read data from file 'College_details.csv' and store in college
college  #Preview the loaded data
# Out:
#   CollegeCode  CSE   IT   ME   EE   EC   IC   CH  ICT  Rank
# 0       C0001    0   60    0  120    0   60   60  120    10
# 1       C0002    0  180   60  120  180  120  120  180     6
# 2       C0003    0   60    0    0  180  180   60   60     8
# 3       C0004   60  120  120    0  120  180    0  120     5
# 4       C0005  180  180   60   60   60    0    0   60     1
# 5       C0006  120  180  180  180   60   60   60  180     3
# 6       C0007  120  180  120  120   60   60   60   60     4
# 7       C0008    0    0  180  120    0    0  180  180     2
# 8       C0009  180    0   60  120  120   60  120    0     7
# 9       C0010   60  180  120  120  180    0  180  180     9

# %% [markdown]
# # Question - 1
# ​
# Q-1 - Generate the studentdetails.csv file. Generate the atleast 10000 students data.(use 50 students instead 10000 students)
# ​
#
# Answer ->
#
#           in this first question declare the so many list to store the data like Enrollmentno, Subject_1 marks,
#           Subject_2 marks, Subject_3 marks, Subject_4 marks, Subject_5 marks, Total of all subject marks
#           In the first list store 50 records of Enrollmentno randomly generate number and it combine with declare variable
#           value 'E' and then Subject_1, Subject_2, Subject_3, Subject_4, Subject_5 in this list insert value using
#           randomly choice the value in between 40 to 100,and last list Total sum all the subject row-wise and store it
#
#           use the zip function to combine multiple list into singal list
#
#           then check the CSV file studentdetails already exist or not if it is exist then remove it and create the
#           new studentdetails.csv file and insert data of the combine list
#
#           and finally print the studentdetails.csv file

# %%
Enrollmentno = list([])  #This List is used to store the Enrollmentno
Subject_1 = list([])  #This List is used to store the Subject_1 values
Subject_2 = list([])  #This List is used to store the Subject_2 values
Subject_3 = list([])  #This List is used to store the Subject_3 values
Subject_4 = list([])  #This List is used to store the Subject_4 values
Subject_5 = list([])  #This List is used to store the Subject_5 values
Total = list([])  #This List is used to store the Total

enroll = 'E'  #variable enroll declare with 'E' will be used as combine with Enrollmentno
for i in range(1,51):  #For Loop to insert 50 records from in Enrollmentno list
    s = ''.join(['{0:05}'.format(i)]) #in variable s assign 00001,00002 base on i 
    ans = enroll+s  #variable ans combine varible enroll and variable s
    Enrollmentno.append(ans)  #variable ans value append in the Enrollmentno list

for i in range(0,50):  #For Loop to insert 50 records from in Subject_1 list
    Subject_1.append((np.random.randint(40,100)))  #choice the random value between 40 and 100 and then append into Subject_1 list
    
for i in range(0,50):  #For Loop to insert 50 records from in Subject_2 list
    Subject_2.append((np.random.randint(40,100)))  #choice the random value between 40 and 100 and then append into Subject_1 list
    
for i in range(0,50):  #For Loop to insert 50 records from in Subject_3 list
    Subject_3.append((np.random.randint(40,100)))  #choice the random value between 40 and 100 and then append into Subject_1 list

for i in range(0,50):  #For Loop to insert 50 records from in Subject_4 list
    Subject_4.append((np.random.randint(40,100)))  #choice the random value between 40 and 100 and then append into Subject_1 list

for i in range(0,50):  #For Loop to insert 50 records from in Subject_5 list
    Subject_5.append((np.random.randint(40,100)))  #choice the random value between 40 and 100 and then append into Subject_1 list
    
for i in range(0,50):  #For Loop to insert 50 records from in Total list
    Total.append(Subject_1[i]+Subject_2[i]+Subject_3[i]+Subject_4[i]+Subject_5[i]) #sum of 5 subject row wise and append into Total list

rows = zip(Enrollmentno,Subject_1,Subject_2,Subject_3,Subject_4,Subject_5,Total)  #zip combine multiple list into one list so all list combine into 'rows'

my_file = Path("studentdetails.csv")  #check the studentdetails.csv file path are avilable or not
if my_file.is_file():  #check file is exist or not
    os.remove('studentdetails.csv')  #if file is exist so remove it

with open('studentdetails.csv','w',newline="\n") as file:  #Open/Create file with 'w' mode.
    writer=csv.writer(file, delimiter=',')  #Declaring writer to write data into studentdetails.csv file.
    writer.writerow(["Enrollmentno", "Subject_1", "Subject_2", "Subject_3", "Subject_4", "Subject_5", "Total"])  #write first row in copy_of_College_details.csv
    for row in rows:  #There are multiple rows in 'rows' list so, each row will be extracted and stored in 'row'
        writer.writerow(row)  #writerow function will write/add new row in studentdetails.csv

students = pd.read_csv("studentdetails.csv")  #Read data from file 'College_details.csv' and store in students

students  #Preview the loaded data
# Out:
#    Enrollmentno  Subject_1  Subject_2  Subject_3  Subject_4  Subject_5  Total
# 0        E00001         55         81         79         57         68    340
# 1        E00002         57         43         55         86         75    316
# 2        E00003         67         91         47         43         79    327
# 3        E00004         81         94         77         66         66    384
# 4        E00005         88         95         63         93         47    386
# 5        E00006         57         66         79         51         84    337
# 6        E00007         85         66         53         53         71    328
# 7        E00008         58         50         42         84         62    296
# 8        E00009         71         40         41         46         75    273
# 9        E00010         73         49         77         93         51    343
# 10       E00011         95         85         41         64         54    339
# ...

# %% [markdown]
# # Question - 2
#
# Q-2 - Give rank to the students so that admission process will be performed in proper sequence. Use any mechanism to
#       give rank to the students.
#
# Answer ->
#
#           in this second question read the studentdetails.csv file using read_csv() function and then assign rank to the
#           'Total' column in descending order means high value assign 1st rank. then create the 'Rank' column in this
#           column assign rank base on 'Total' column rank in descending order and last sort the all record descending order
#           base on 'Total' column.
#
#           and finally print the studentdetails.csv file

# %%
students = pd.read_csv("studentdetails.csv")  #Read data from file 'studentdetails.csv' and store in students

students["Total"].rank(ascending=False).astype(int)  #give the rank of column 'Total' in descending order
students["Rank"] = students["Total"].rank(ascending=False).astype(int)  #create the column name 'Rank' given the rank base on the column 'Total' in descending order
exam = students.sort_values(by = "Total", ascending=False)  #sort the all recode descending order base on column 'Total' 
exam  #Preview the loaded data
# Out:
#    Enrollmentno  Subject_1  Subject_2  Subject_3  Subject_4  Subject_5  Total  \
# 20       E00021         81         81         97         83         82    424
# 36       E00037         68         91         80         99         83    421
# 45       E00046         65         68         81         93         99    406
# 38       E00039         71         75         59         99         88    392
# 4        E00005         88         95         63         93         47    386
# 3        E00004         81         94         77         66         66    384
# 39       E00040         83         92         65         99         45    384
# 17       E00018         98         62         83         53         86    382
# 31       E00032         80         79         64         59         97    379
# 34       E00035         85         93         51         60         89    378
# 29       E00030         48         41         98         86         99    372
# ...

# %% [markdown]
# # Question - 3 & Question - 4
#
# Q-3 - Before generating the choice_filling.csv file, ask user to give atleast 3 preferable branch code in which they want to           take admission and generate the data based on the branch choice entered by student and store in the choice_filling.csv           file. Also make sure student preferred to get admission in higher rank colleges so take this constrains in the                   consideration while generating data. First generate the data for 500 students and try to give them admission in their           preferable college and branch. Every day, the admission process of 500 students is carried out by the system.
#       (use 10 students instead 500 students give them addmission)
#
# Q-4 - At the end of first day of admission process, generate day1_college_status.csv file, which has details like number of           vacant seats, branch wise, in all the colleges that will available for admission process on day 2. Perform the step 3
#       and step 4 iteratively until entire admission process get over.
#
# Answer ->
#
#           in this 3 and 4 question first of all declare some necessary list and then start and end list given the college
#           rank boundary means that in between rank student eligible for this college then create the report.csv file this
#           file store some necessary data is use to next question then create the for loop thay start from 1 and end 51
#           and increment by 10 means Total number of student increment by total number of student given admission per 1 day
#           then create another for loop to process 10 students per 1 day then ask the Enrollmentno from the user and check
#           it available in studentdetails.csv file or not if its not in studentdetails.csv file than again ask the user to
#           enter the Enrollmentno also check enter Enrollmentno is not present in choice_filling.csv file if it present
#           than also again ask the user to enter the Enrollmentno the then ask the user to enter the 3 preferable branch
#           in which they want to take admission if user enter same branch it does not allow and give the error message to
#           choice another branch because This Branch You have already Choice after the choice 3 branch then print the
#           data which contain all collegecode 3 branch that you have choice and rank of the college and display all record
#           ascending order base on rank after the display record ask the user to choice and 10 colleges that you have
#           to get admission user enter the collegecode check this collegecode is vailable in copy_of_College_details.csv file
#           or not if its not in copy_of_College_details.csv file than again ask the user to enter the collegecode then ask
#           the branch from the user and check this entered branch is available in previously choice 3 branch if it is not
#           than ask again to enter the branch if it available then check the seat are available or not if seat is 0 then
#           again ask the collegecode and branch if seat are greater than 0 then store the codecode-branch in one variable
#           and check this choice is previously enter or not if it is same as previouslay choice codecode-branch then give
#           the error message same choice are not available if it is not same than data store in list also set the logic
#           which give the admission of the student on the spot so that logic is set check = 0 on procees will be start to
#           get student enrollmentno and the main logic is if found the check = 0 means this student given not any seat and
#           then check the student rank is eligible for the choicing colloge or not if it is eligible than assign seat to
#           the students and set check = 1 means do not execute this process again to assign seat and than perticular
#           seat decreasing by one and also store the record of allocate collegecode-branch and enrollmentno in report.csv
#           file and also update the copy_of_College_details.csv file also count the seat branch wise to allocate student
#           its use in next question the process of choice_filling is continue 10 time per 1 student than choice_filling
#           data and Enrollmentno store in choice_filling.csv file and choice the 10 recode after show the your
#           choice_filling data
#           if finish the 10 student per day then all the data of the copy_of_College_details.csv file copy into
#           the day1_college_status.csv file and this process will be execute 5 day means that total 50 student per day
#           10 studnents and file name should be day1_college_status.csv,day2_college_status.csv,day3_college_status.csv,
#           day4_college_status.csv,day5_college_status.csv

# %%
class NegativeNum(Exception):  #catch NegativeNum exception
    pass
Enrollment = list([])  #This List is used to store the Enrollment values
branch2 = list([])  #This List is used to store the branch2 values
S_Choice = list([])  #This List is used to store the S_Choice values
temp = list([])  #This List is used to store the temp values
temp1 = list([])  #This List is used to store the temp1 values
temp2 = list([])  #This List is used to store the temp2 values
code = list([])  #This List is used to store the code values
start = ([])  #This List is used to store the start values
end = ([])  #This List is used to store the end values
for i in range(0,100,10):  # For Loop to insert 50 records from 'start' and 'end'
    a = i+1  #i increment by 1
    start.append(a)  #append value of a into start
    b = i+10  #i increment by 10
    end.append(b)  ##append value of b into start
    
count=0  #declare count=0
day=0  #declare day=0
t_cse = 0  #declare t_cse=0
t_it = 0  #declare t_it=0
t_me = 0  #declare t_me=0
t_ee = 0  #declare t_ee=0
t_ec = 0  #declare t_ec=0
t_ic = 0  #declare t_ic=0
t_ch = 0  #declare t_ch=0
t_ict = 0  #declare t_ict=0
with open('report.csv','w',newline="\n") as file:  #Open/Create file with 'w' mode
    writer=csv.writer(file, delimiter=',')  #Declaring writer to write data into report.csv file
    writer.writerow(["CollegeCode_Branch", "EnrollmentNo"])  #write first row in report.csv
    
for d in range(1,51,10):  #For Loop to start from 1 and end 51 and increment by 10  #Total number of student increment by total number of student given admission per 1 day
    day = day + 1  #day increment by 1
    print("\n***** Day {} *****".format(day))  #print this line with the value of day
    for s in range(1,11): #For Loop insert the 10 record of the student per day 
            flagt=0 #set flagt = 0 when given the wrong input flagt set 0 and process begin execute here
            while flagt==0: #for continuos process
                en=pd.read_csv("studentdetails.csv")  #All the data of studentdetails.csv is stored in 'en'
                en_data=np.array(en['Enrollmentno'])  #Enrollmentno column is extracted out from 'en' and stored in 'en_data' Array
                Enrollno = random.choice(en_data)  #randomlly choice the data from the 'en_data' Array
                print("Enter Enrollmentno ::- {}".format(Enrollno))  #print this line with 'Enrollno' value
                #Enrollno = input("Enter Enrollmentno ::- ")
                #print("Enrollmentno is: " + Enrollno)

                is_in_file = False  #set is_in_file is false
                is_in_file_choice_filling = False  #set is_in_file_choice_filling is false
                with open('studentdetails.csv', 'rt') as f:  #Open file with 'rt' mode
                    reader = csv.reader(f, delimiter=',')  #Declaring reader to read data into studentdetails.csv file
                    for row in reader:  #There are multiple rows in 'reader' so, each row will be extracted and stored in 'row'
                        for field in row:  #There are multiple rows in 'row' so, each row will be extracted and stored in 'field'
                            if field == Enrollno:  #check if field value match the Enrollno value then if condition execute
                                is_in_file = True  #if if condition Satisfy then set is_in_file = True
                                flagt=1  #set flagt = 1 so process not execute again
                    if is_in_file == False:  #if field value do not match the Enrollno value set is_in_file = False
                        print("Enrollno Is Not Found")  #print the error message
                        flagt=0  #set flagt = 0 so process will execute again
                        continue  #continue the process for begin execute

                my_file = Path("choice_filling.csv")  #check the choice_filling.csv file path are avilable or not
                if my_file.is_file():  #check file is exist or not
                    print()  #this statement nothing will be print
                else:  # if choice_filling.csv will not created then create this file
                    with open('choice_filling.csv','a',newline="") as file:  #Open/Create file with 'w' mode
                        writer=csv.writer(file)  #Declaring writer to write data into choice_filling.csv file
                        writer.writerow(['Enrollmentno', 'choice1', 'choice2', 'choice3', 'choice4', 'choice5', 'choice6', 'choice7', 'choice8', 'choice9', 'choice10'])  #write first row in choice_filling.csv

                with open('choice_filling.csv', 'rt') as f:  #Open file with 'rt' mode
                    reader = csv.reader(f, delimiter=',')  #Declaring reader to read data into choice_filling.csv file
                    for row in reader:  #There are multiple rows in 'reader' so, each row will be extracted and stored in 'row'
                        for field in row:  #There are multiple rows in 'row' so, each row will be extracted and stored in 'field'
                            if field == Enrollno:  #check if field value match the Enrollno value if condition execute
                                is_in_file_choice_filling = True  #if if condition Satisfy then set is_in_file_choice_filling = True

                    if is_in_file_choice_filling == True: #if is_in_file_choice_filling = true means student enter same Enrollmentno that Previously entered means that not allow
                        print("Opps. Your Information is already Store You Can`t Choice_Filling")  #give the error message
                        flagt=0  #set flagt = 0 so process will execute again
                        continue  #continue the process for begin execute
                flagt=1  #if satisfy all the condition then set flagt = 1 so process not execute again

            if is_in_file == True and is_in_file_choice_filling == False:  #if is_in_file == True and is_in_file_choice_filling == False then execute below condition
                Enrollment.append(Enrollno)  #Enrollno value append into Enrollment list
                print("Enter the 3 Branch That You want to get Admission ::- \n")  #print this line
                print("1) CSE") #print this line
                print("2) IT") #print this line
                print("3) ME") #print this line
                print("4) EE") #print this line
                print("5) EC") #print this line
                print("6) IC") #print this line
                print("7) CH") #print this line
                print("8) ICT") #print this line
                flag=0 #set flag = 0 when given the wrong input flagt set 0 and process begin execute here
                while flag==0:  #for continuos process
                    try:  #to handled exception
                        foo = [1,2,3,4,5,6,7,8]  #list foo declare with 0,60,120,180 value
                        a = random.choice(foo)  #Random Choice value from the foo-list and asign to the 'a'
                        print("Enter Branch 1 ::- {}".format(a))  #print this line with value of 'a'
                        #a=int(input("Enter Branch 1 ::- "))
                        if a<0: #check a is negative or not
                            raise NegativeNum  #if a is nagative raise this exception
                        else: #is not nagative then execute below statemnet
                            if a==1: #if a=1 then
                                if "CSE" in branch2: #check the given choice value is already exist in branch2 list or not if exist then
                                    print("This Branch You have already Choice plz Choice Another Branch")  #give this error message 
                                    continue  #continue the process for begin execute
                                else: #if given choice value is not exist then
                                    branch2.append("CSE")  #'CSE' append into 'branch2' list
                            elif a==2:  #if a=2 then
                                if "IT" in branch2:  #check the given choice value is already exist in branch2 list or not if exist then
                                    print("This Branch You have already Choice plz Choice Another Branch")  #give this error message
                                    continue  #continue the process for begin execute
                                else:  #if given choice value is not exist then
                                    branch2.append("IT")  #'IT' append into 'branch2' list
                            elif a==3:  #if a=3 then
                                if "ME" in branch2:  #check the given choice value is already exist in branch2 list or not if exist then
                                    print("This Branch You have already Choice plz Choice Another Branch")  #give this error message
                                    continue  #continue the process for begin execute
                                else: #if given choice value is not exist then
                                    branch2.append("ME")  #'ME' append into 'branch2' list
                            elif a==4:  #if a=4 then
                                if "EE" in branch2:  #check the given choice value is already exist in branch2 list or not if exist then
                                    print("This Branch You have already Choice plz Choice Another Branch")  #give this error message
                                    continue  #continue the process for begin execute
                                else:  #if given choice value is not exist then
                                    branch2.append("EE")  #'EE' append into 'branch2' list
                            elif a==5:  #if a=5 then
                                if "EC" in branch2:  #check the given choice value is already exist in branch2 list or not if exist then
                                    print("This Branch You have already Choice plz Choice Another Branch")  #give this error message
                                    continue  #continue the process for begin execute
                                else:  #if given choice value is not exist then
                                    branch2.append("EC")  #'EC' append into 'branch2' list
                            elif a==6:  #if a=6 then
                                if "IC" in branch2:  #check the given choice value is already exist in branch2 list or not if exist then
                                    print("This Branch You have already Choice plz Choice Another Branch")  #give this error message
                                    continue  #continue the process for begin execute
                                else:  #if given choice value is not exist then
                                    branch2.append("IC")  #'IC' append into 'branch2' list
                            elif a==7:  #if a=7 then
                                if "CH" in branch2:  #check the given choice value is already exist in branch2 list or not if exist then
                                    print("This Branch You have already Choice plz Choice Another Branch")  #give this error message
                                    continue  #continue the process for begin execute
                                else:  #if given choice value is not exist then
                                    branch2.append("CH")  #'CH' append into 'branch2' list
                            elif a==8:  #if a=8 then
                                if "ICT" in branch2:  #check the given choice value is already exist in branch2 list or not if exist then
                                    print("This Branch You have already Choice plz Choice Another Branch")  #give this error message
                                    continue  #continue the process for begin execute
                                else:  #if given choice value is not exist then
                                    branch2.append("ICT")  #'ICT' append into 'branch2' list
                            else:  #if not enter valid number then
                                print("Enter Valid Number")  #give the error message
                                continue  #continue the process for begin execute
                    except NegativeNum:  #catch NegativeNum exception
                        print("Enter Positive number")  #give the error message
                        continue  #continue the process for begin execute
                    except ValueError:  #catch valueerror exception
                        print("Non-numeric data found in the file")  #give the error message
                        continue  #continue the process for begin execute
                    flag=1  #if satisfy all the condition then set flag = 1 so process not execute again

                flag=0 #set flag = 0 when given the wrong input flagt set 0 and process begin execute here
                while flag==0:  #for continuos process
                    try:  #to handled exception
                        foo = [1,2,3,4,5,6,7,8]  #list foo declare with 0,60,120,180 value
                        a = random.choice(foo)  #Random Choice value from the foo-list and asign to the 'a'
                        print("Enter Branch 2 ::- {}".format(a))  #print this line with value of 'a'
                        #a=int(input("Enter Branch 2 ::- "))
                        if a<0: #check a is negative or not
                            raise NegativeNum  #if a is nagative raise this exception
                        else: #is not nagative then execute below statemnet
                            if a==1: #if a=1 then
                                if "CSE" in branch2: #check the given choice value is already exist in branch2 list or not if exist then
                                    print("This Branch You have already Choice plz Choice Another Branch")  #give this error message 
                                    continue  #continue the process for begin execute
                                else: #if given choice value is not exist then
                                    branch2.append("CSE")  #'CSE' append into 'branch2' list
                            elif a==2:  #if a=2 then
                                if "IT" in branch2:  #check the given choice value is already exist in branch2 list or not if exist then
                                    print("This Branch You have already Choice plz Choice Another Branch")  #give this error message
                                    continue  #continue the process for begin execute
                                else:  #if given choice value is not exist then
                                    branch2.append("IT")  #'IT' append into 'branch2' list
                            elif a==3:  #if a=3 then
                                if "ME" in branch2:  #check the given choice value is already exist in branch2 list or not if exist then
                                    print("This Branch You have already Choice plz Choice Another Branch")  #give this error message
                                    continue  #continue the process for begin execute
                                else: #if given choice value is not exist then
                                    branch2.append("ME")  #'ME' append into 'branch2' list
                            elif a==4:  #if a=4 then
                                if "EE" in branch2:  #check the given choice value is already exist in branch2 list or not if exist then
                                    print("This Branch You have already Choice plz Choice Another Branch")  #give this error message
                                    continue  #continue the process for begin execute
                                else:  #if given choice value is not exist then
                                    branch2.append("EE")  #'EE' append into 'branch2' list
                            elif a==5:  #if a=5 then
                                if "EC" in branch2:  #check the given choice value is already exist in branch2 list or not if exist then
                                    print("This Branch You have already Choice plz Choice Another Branch")  #give this error message
                                    continue  #continue the process for begin execute
                                else:  #if given choice value is not exist then
                                    branch2.append("EC")  #'EC' append into 'branch2' list
                            elif a==6:  #if a=6 then
                                if "IC" in branch2:  #check the given choice value is already exist in branch2 list or not if exist then
                                    print("This Branch You have already Choice plz Choice Another Branch")  #give this error message
                                    continue  #continue the process for begin execute
                                else:  #if given choice value is not exist then
                                    branch2.append("IC")  #'IC' append into 'branch2' list
                            elif a==7:  #if a=7 then
                                if "CH" in branch2:  #check the given choice value is already exist in branch2 list or not if exist then
                                    print("This Branch You have already Choice plz Choice Another Branch")  #give this error message
                                    continue  #continue the process for begin execute
                                else:  #if given choice value is not exist then
                                    branch2.append("CH")  #'CH' append into 'branch2' list
                            elif a==8:  #if a=8 then
                                if "ICT" in branch2:  #check the given choice value is already exist in branch2 list or not if exist then
                                    print("This Branch You have already Choice plz Choice Another Branch")  #give this error message
                                    continue  #continue the process for begin execute
                                else:  #if given choice value is not exist then
                                    branch2.append("ICT")  #'ICT' append into 'branch2' list
                            else:  #if not enter valid number then
                                print("Enter Valid Number")  #give the error message
                                continue  #continue the process for begin execute
                    except NegativeNum:  #catch NegativeNum exception
                        print("Enter Positive number")  #give the error message
                        continue  #continue the process for begin execute
                    except ValueError:  #catch valueerror exception
                        print("Non-numeric data found in the file")  #give the error message
                        continue  #continue the process for begin execute
                    flag=1  #if satisfy all the condition then set flag = 1 so process not execute again

                flag=0 #set flag = 0 when given the wrong input flag set 0 and process begin execute here
                while flag==0:  #for continuos process
                    try:  #to handled exception
                        foo = [1,2,3,4,5,6,7,8]  #list foo declare with 0,60,120,180 value
                        a = random.choice(foo)  #Random Choice value from the foo-list and asign to the 'a'
                        print("Enter Branch 3 ::- {}".format(a))  #print this line with value of 'a'
                        #a=int(input("Enter Branch 3 ::- "))
                        if a<0: #check a is negative or not
                            raise NegativeNum  #if a is nagative raise this exception
                        else: #is not nagative then execute below statemnet
                            if a==1: #if a=1 then
                                if "CSE" in branch2: #check the given choice value is already exist in branch2 list or not if exist then
                                    print("This Branch You have already Choice plz Choice Another Branch")  #give this error message 
                                    continue  #continue the process for begin execute
                                else: #if given choice value is not exist then
                                    branch2.append("CSE")  #'CSE' append into 'branch2' list
                            elif a==2:  #if a=2 then
                                if "IT" in branch2:  #check the given choice value is already exist in branch2 list or not if exist then
                                    print("This Branch You have already Choice plz Choice Another Branch")  #give this error message
                                    continue  #continue the process for begin execute
                                else:  #if given choice value is not exist then
                                    branch2.append("IT")  #'IT' append into 'branch2' list
                            elif a==3:  #if a=3 then
                                if "ME" in branch2:  #check the given choice value is already exist in branch2 list or not if exist then
                                    print("This Branch You have already Choice plz Choice Another Branch")  #give this error message
                                    continue  #continue the process for begin execute
                                else: #if given choice value is not exist then
                                    branch2.append("ME")  #'ME' append into 'branch2' list
                            elif a==4:  #if a=4 then
                                if "EE" in branch2:  #check the given choice value is already exist in branch2 list or not if exist then
                                    print("This Branch You have already Choice plz Choice Another Branch")  #give this error message
                                    continue  #continue the process for begin execute
                                else:  #if given choice value is not exist then
                                    branch2.append("EE")  #'EE' append into 'branch2' list
                            elif a==5:  #if a=5 then
                                if "EC" in branch2:  #check the given choice value is already exist in branch2 list or not if exist then
                                    print("This Branch You have already Choice plz Choice Another Branch")  #give this error message
                                    continue  #continue the process for begin execute
                                else:  #if given choice value is not exist then
                                    branch2.append("EC")  #'EC' append into 'branch2' list
                            elif a==6:  #if a=6 then
                                if "IC" in branch2:  #check the given choice value is already exist in branch2 list or not if exist then
                                    print("This Branch You have already Choice plz Choice Another Branch")  #give this error message
                                    continue  #continue the process for begin execute
                                else:  #if given choice value is not exist then
                                    branch2.append("IC")  #'IC' append into 'branch2' list
                            elif a==7:  #if a=7 then
                                if "CH" in branch2:  #check the given choice value is already exist in branch2 list or not if exist then
                                    print("This Branch You have already Choice plz Choice Another Branch")  #give this error message
                                    continue  #continue the process for begin execute
                                else:  #if given choice value is not exist then
                                    branch2.append("CH")  #'CH' append into 'branch2' list
                            elif a==8:  #if a=8 then
                                if "ICT" in branch2:  #check the given choice value is already exist in branch2 list or not if exist then
                                    print("This Branch You have already Choice plz Choice Another Branch")  #give this error message
                                    continue  #continue the process for begin execute
                                else:  #if given choice value is not exist then
                                    branch2.append("ICT")  #'ICT' append into 'branch2' list
                            else:  #if not enter valid number then
                                print("Enter Valid Number")  #give the error message
                                continue  #continue the process for begin execute
                    except NegativeNum:  #catch NegativeNum exception
                        print("Enter Positive number")  #give the error message
                        continue  #continue the process for begin execute
                    except ValueError:  #catch valueerror exception
                        print("Non-numeric data found in the file")  #give the error message
                        continue  #continue the process for begin execute
                    flag=1  #if satisfy all the condition then set flag = 1 so process not execute again

                #print(branch)
                branch1 = list([])  #This List is used to store the branch1 values
                branch1.append("CollegeCode") # "CollegeCode" string append to the branch1 list
                for x in branch2: #this for loop extract the data of branch2 list and store in x one by one
                      branch1.append(x) #append the data of x into branch1 list
                branch1.append("Rank") # "Rank" string append to the branch1 list

                print("\n***********************************")
                print("********** Your Data **************")
                print("***********************************")
                college = pd.read_csv("copy_of_College_details.csv",usecols=branch1,nrows=50) #Read data from file 'copy_of_College_details.csv' and store in college with use column that strore in branch1 list
                sorted_df = college.sort_values(by='Rank') #sort the college by the 'Rank'
                #print(sorted_df.head(10))
                #print(sorted_df.tail(50))
                print(sorted_df) #print the data

                check = 0 #set check = 0
                print("\nEnter The 10 Choice ::- ")
                for c in range(1,11):  #for loop for 10 choice_filling by the students
                    is_in_file_collegecode = False  #set is_in_file_collegecode = false
                    is_in_file_branchchoice = False  #set is_in_file_branchchoice = false
                    is_in_file_seat = False  #set is_in_file_seat = false
                    flag=0  #set flag = 0 when given the wrong input flag set 0 and process begin execute here
                    while flag==0: #for continuos process
                        flag1=0  #set flag1 = 0 when given the wrong input flag1 set 0 and process begin execute here
                        while flag1==0: #for continuos process
                            read3=pd.read_csv("copy_of_College_details.csv")  #Read data from file 'copy_of_College_details.csv' and store in read3
                            CollegeCode1=np.array(read3['CollegeCode'])  #CollegeCode column is extracted out from 'read3' and stored in 'CollegeCode1' Array
                            collegecode = random.choice(CollegeCode1)  #randomlly choice the data from the 'CollegeCode1' Array and store in collegecode
                            print("Enter CollegeCode {} ::- {}".format(c,collegecode))  #print this line with value of c and value of collegecode
                            #collegecode = input("Enter CollegeCode {} ::- ".format(c))
                            for i in range(0,10):  #for loop for check the given collegecode is exist in CollegeCode1 array or not
                                    if CollegeCode1[i] == collegecode: #check the given college is match with CollegeCode1 if exist then
                                            is_in_file_collegecode = True  #set is_in_file_collegecode = true

                            if is_in_file_collegecode == False:  #if is_in_file_collegecode = false then
                                print("CollegeCode Is Not Found")  #give the error message
                                flag1=0  #set flag1 = 0 so process will execute again
                                continue #continue the process for begin execute
                            else:  #if is_in_file_collegecode = true then
                                collegechoice = collegecode #asign value of collegecode to collegechoice
                                
                            br = random.choice(branch2) #randomally choice the branch in the branch2 list
                            print("Enter Branch {} ::- {}".format(c,br))  #print this line with value of c and value of br
                            #br = input("Enter Branch {} ::- ".format(c))
                            with open('copy_of_College_details.csv', 'rt') as f:  #Open file with 'rt' mode
                                reader = csv.reader(f, delimiter=',')  #Declaring reader to read data into copy_of_College_details.csv file
                                for row in reader:  #There are multiple rows in 'reader' so, each row will be extracted and stored in 'row'
                                    for field in row:  #There are multiple rows in 'row' so, each row will be extracted and stored in 'field'
                                        if field == br:  #check if field value match the br value then if condition execute
                                            if br in branch1: #check if br value exist in branch1 list or not
                                                is_in_file_branchchoice = True #if exist then set is_in_file_branchchoice=true

                                if is_in_file_branchchoice == False: #if is_in_file_branchchoice = false then
                                    print("Branch Is Not Found")  #error message print
                                    flag1=0 #set flag1 = 0 so process will execute again
                                    continue #continue the process for begin execute
                                if br=='CSE': #check if br value is 'CSE' then
                                    a=1 #set a = 1
                                elif br=='IT':  #check if br value is 'IT' then
                                    a=2  #set a = 2
                                elif br=='ME':  #check if br value is 'ME' then
                                    a=3  #set a = 3
                                elif br=='EE':  #check if br value is 'EE' then
                                    a=4  #set a = 4
                                elif br=='EC':  #check if br value is 'EC' then
                                    a=5  #set a = 5
                                elif br=='IC':  #check if br value is 'IC' then
                                    a=6  #set a = 6
                                elif br=='CH':  #check if br value is 'CH' then
                                    a=7  #set a = 7
                                elif br=='ICT':  #check if br value is 'ICT' then
                                    a=8  #set a = 8
                                read1=pd.read_csv("copy_of_College_details.csv")  #Read data from file 'copy_of_College_details.csv' and store in read1
                                CollegeCode=np.array(read1['CollegeCode'])  #CollegeCode column is extracted out from 'read1' and stored in 'CollegeCode' Array
                                CSE=np.array(read1['CSE'])  #CSE column is extracted out from 'read1' and stored in 'CSE' Array
                                IT=np.array(read1['IT'])  #IT column is extracted out from 'read1' and stored in 'IT' Array
                                ME=np.array(read1['ME'])  #ME column is extracted out from 'read1' and stored in 'ME' Array
                                EE=np.array(read1['EE'])  #EE column is extracted out from 'read1' and stored in 'EE' Array
                                EC=np.array(read1['EC'])  #EC column is extracted out from 'read1' and stored in 'EC' Array
                                IC=np.array(read1['IC'])  #IC column is extracted out from 'read1' and stored in 'IC' Array
                                CH=np.array(read1['CH'])  #CH column is extracted out from 'read1' and stored in 'CH' Array
                                ICT=np.array(read1['ICT'])  #ICT column is extracted out from 'read1' and stored in 'ICT' Array
                                Rank=np.array(read1['Rank'])  #Rank column is extracted out from 'read1' and stored in 'Rank' Array
                                for i in range(0,10):  #for loop for append all the array
                                    temp.append([CollegeCode[i],CSE[i],IT[i],ME[i],EE[i],EC[i],IC[i],CH[i],ICT[i],Rank[i]])  #append all the array into 'temp' list              
                                for i in range(len(temp)):
                                    for e in temp:  #There are multiple rows in 'temp' so, each row will be extracted and stored in 'e'
                                        if(e[0]==collegecode and e[a] > 0): #check e[0] match the collegecode and e[a] value > 0 means a is previously set according selected branch and branch seat is greater then 0  
                                            is_in_file_seat=True #if above condition is true then set is_in_file_seat = true
                                            break #if condition is satisfy break the loop so process time is less
                                if is_in_file_seat==False:  #if is_in_file_seat = false then
                                    print("Seat are Not Available")  #give the error message
                                    flag1=0  #set flag1 = 0 so process will execute again
                                    continue  #continue the process for begin execute
                                else:  #if is_in_file_seat = true then
                                    branchchoice = br  #asign value of br to branchchoice
                                flag1=1 #if satisfy all the condition then set flag1 = 1 so process not execute again
                        ans = collegechoice+"-"+branchchoice  # asign data into 'ans' with 'collegechoice' value '-' 'branchchoice' value like C0001-CSE
                        if ans in S_Choice: #check 'ans' is already exist in S_Choice list or not if exist then
                            flag=0  #set flag = 0 so process will execute again
                            print("Same Record are not allow") #give the error message
                            continue  #continue the process for begin execute
                        else: #if ans is not exist in S_Choice list then
                            S_Choice.append(ans)  #ans value append into the S_Choice
                            #below process is asign seat the student if it eligible for this college means if check = 0 then this student not assign any seat
                            #if check = 1 then this student assign a seat so this process will no execute again
                            if check == 0: #if check = 0 then 
                                students = pd.read_csv("studentdetails.csv")  #Read data from file 'studentdetails.csv' and store in students
                                students["Total"].rank(ascending=False).astype(int)  #give the rank of column 'Total' in descending order
                                students["Rank"] = students["Total"].rank(ascending=False).astype(int)  #create the column name 'Rank' given the rank base on the column
                                exam = students.sort_values(by = "Total", ascending=False)  #sort the all recode descending order base on column 'Total'
                                Enrollmentno1=np.array(exam['Enrollmentno'])  #Enrollmentno column is extracted out from 'exam' and stored in 'Enrollmentno1' Array
                                Ranks=np.array(exam['Rank'])  #Rank column is extracted out from 'exam' and stored in 'Ranks' Array
                                for i in range(0,50):  #for-loop
                                    if Enrollmentno1[i] == Enrollno: #if Enrollmentno1 match Enrollno then
                                        temp1.append(Enrollmentno1[i]) #append the Enrollmentno1[i] into the temp1 list
                                        temp1.append(Ranks[i]) #append the Ranks[i] into the temp1 list

                                read3=pd.read_csv("copy_of_College_details.csv")  #Read data from file 'copy_of_College_details.csv' and store in read3
                                CollegeCode1=np.array(read3['CollegeCode'])  #CollegeCode column is extracted out from 'read3' and stored in 'CollegeCode1' Array
                                branch=np.array(read3[br])  #value of br column is extracted out from 'read3' and stored in 'branch' Array
                                Rankc=np.array(read3['Rank'])  #Rank column is extracted out from 'read3' and stored in 'Rankc' Array
                                for i in range(0,10): 
                                    if CollegeCode1[i] == collegecode:  #if CollegeCode1[i] value match with collegecode value then
                                        h=i  #assign i value to h
                                        temp2.append(CollegeCode1[i])  #value of CollegeCode1[i] is append into temp2 list
                                        temp2.append(branch[i]) #value of branch[i] is append into temp2 list
                                        temp2.append(Rankc[i]) #value of Rankc[i] is append into temp2 list
                                        temp2.append(start[i]) #value of start[i] is append into temp2 list
                                        temp2.append(end[i]) #value of end[i] is append into temp2 list

                                for x in temp2: #for-loop to append all temp2 data into temp1
                                    temp1.append(x)
                                #['E00004', 1, 'C0006', 180, 3, 21, 30]       
                                if temp1[1] <= temp1[6]: #if temp1[1] value is less then or equals to temp1[6] value then
                                    check = 1 #if above condition is true then set check = 1
                                    temp1[3] = temp1[3]-1 #set temp1[3] = temp1[3] - 1 because 1 seat allocate to the student so seat decrement by 1 
                                    branch[h] = temp1[3] #in branch array update this record
                                    ans = collegecode+"-"+br  #asign data into 'ans' with 'collegecode' value '-' 'br' value like C0005-EE
                                    temp_data = [ans,Enrollno]  #append the ans value and Enrollno value into the temp_data list
                                    with open('report.csv','a',newline="") as file:  #Open/Create file with 'a' mode
                                        writer=csv.writer(file)  #Declaring writer to write data into report.csv file
                                        writer.writerow(temp_data)  #writerow function will write/add new row in report.csv
                                    
                                    if br=='CSE':  #if br value 'CSE' then
                                        t_cse = t_cse + 1  #t_cse increment by 1
                                    elif br=='IT':  #if br value 'IT' then
                                        t_it = t_it + 1  #t_it increment by 1
                                    elif br=='ME':  #if br value 'ME' then
                                        t_me = t_me + 1  #t_me increment by 1
                                    elif br=='EE':  #if br value 'EE' then
                                        t_ee = t_ee + 1  #t_ee increment by 1
                                    elif br=='EC':  #if br value 'EC' then
                                        t_ec = t_ec + 1  #t_ec increment by 1
                                    elif br=='IC':  #if br value 'IC' then
                                        t_ic = t_ic + 1  #t_ic increment by 1
                                    elif br=='CH':  #if br value 'CH' then
                                        t_ch = t_ch + 1  #t_ch increment by 1
                                    elif br=='ICT':  #if br value 'ICT' then
                                        t_ict = t_ict + 1  #t_ict increment by 1
                                    
                                    #below process update the hole copy_of_College_details.csv file
                                    if br=='CSE':  #if br value 'CSE' then
                                        rows = zip(CollegeCode,branch,IT,ME,EE,EC,IC,CH,ICT,Rank)  #zip combine multiple list into one list so all list combine into 'rows' 
                                        with open('copy_of_College_details.csv','w',newline="\n") as file:  #Open/Create file with 'w' mode.
                                            writer=csv.writer(file, delimiter=',')  #Declaring writer to write data into copy_of_College_details.csv file.
                                            writer.writerow(["CollegeCode", "CSE", "IT", "ME", "EE", "EC", "IC", "CH", "ICT", "Rank"])  #write first row in copy_of_College_details.csv
                                            for row in rows:  #There are multiple rows in 'rows' list so, each row will be extracted and stored in 'row'
                                                writer.writerow(row)  #writerow function will write/add new row in copy_of_College_details.csv.
                                    elif br=='IT':  #if br value 'IT' then
                                        rows = zip(CollegeCode,CSE,branch,ME,EE,EC,IC,CH,ICT,Rank)  #zip combine multiple list into one list so all list combine into 'rows' 
                                        with open('copy_of_College_details.csv','w',newline="\n") as file:  #Open/Create file with 'w' mode.
                                            writer=csv.writer(file, delimiter=',')  #Declaring writer to write data into copy_of_College_details.csv file.
                                            writer.writerow(["CollegeCode", "CSE", "IT", "ME", "EE", "EC", "IC", "CH", "ICT", "Rank"])  #write first row in copy_of_College_details.csv
                                            for row in rows:  #There are multiple rows in 'rows' list so, each row will be extracted and stored in 'row'
                                                writer.writerow(row)  #writerow function will write/add new row in copy_of_College_details.csv.
                                    elif br=='ME':  #if br value 'ME' then
                                        rows = zip(CollegeCode,CSE,IT,branch,EE,EC,IC,CH,ICT,Rank)  #zip combine multiple list into one list so all list combine into 'rows' 
                                        with open('copy_of_College_details.csv','w',newline="\n") as file:  #Open/Create file with 'w' mode.
                                            writer=csv.writer(file, delimiter=',')  #Declaring writer to write data into copy_of_College_details.csv file.
                                            writer.writerow(["CollegeCode", "CSE", "IT", "ME", "EE", "EC", "IC", "CH", "ICT", "Rank"])  #write first row in copy_of_College_details.csv
                                            for row in rows:  #There are multiple rows in 'rows' list so, each row will be extracted and stored in 'row'
                                                writer.writerow(row)  #writerow function will write/add new row in copy_of_College_details.csv.
                                    elif br=='EE':  #if br value 'EE' then
                                        rows = zip(CollegeCode,CSE,IT,ME,branch,EC,IC,CH,ICT,Rank)  #zip combine multiple list into one list so all list combine into 'rows' 
                                        with open('copy_of_College_details.csv','w',newline="\n") as file:  #Open/Create file with 'w' mode.
                                            writer=csv.writer(file, delimiter=',')  #Declaring writer to write data into copy_of_College_details.csv file.
                                            writer.writerow(["CollegeCode", "CSE", "IT", "ME", "EE", "EC", "IC", "CH", "ICT", "Rank"])  #write first row in copy_of_College_details.csv
                                            for row in rows:  #There are multiple rows in 'rows' list so, each row will be extracted and stored in 'row'
                                                writer.writerow(row)  #writerow function will write/add new row in copy_of_College_details.csv.
                                    elif br=='EC':  #if br value 'EC' then
                                        rows = zip(CollegeCode,CSE,IT,ME,EE,branch,IC,CH,ICT,Rank)  #zip combine multiple list into one list so all list combine into 'rows' 
                                        with open('copy_of_College_details.csv','w',newline="\n") as file:  #Open/Create file with 'w' mode.
                                            writer=csv.writer(file, delimiter=',')  #Declaring writer to write data into copy_of_College_details.csv file.
                                            writer.writerow(["CollegeCode", "CSE", "IT", "ME", "EE", "EC", "IC", "CH", "ICT", "Rank"])  #write first row in copy_of_College_details.csv
                                            for row in rows:  #There are multiple rows in 'rows' list so, each row will be extracted and stored in 'row'
                                                writer.writerow(row)  #writerow function will write/add new row in copy_of_College_details.csv.
                                    elif br=='IC':  #if br value 'IC' then
                                        rows = zip(CollegeCode,CSE,IT,ME,EE,EC,branch,CH,ICT,Rank)  #zip combine multiple list into one list so all list combine into 'rows' 
                                        with open('copy_of_College_details.csv','w',newline="\n") as file:  #Open/Create file with 'w' mode.
                                            writer=csv.writer(file, delimiter=',')  #Declaring writer to write data into copy_of_College_details.csv file.
                                            writer.writerow(["CollegeCode", "CSE", "IT", "ME", "EE", "EC", "IC", "CH", "ICT", "Rank"])  #write first row in copy_of_College_details.csv
                                            for row in rows:  #There are multiple rows in 'rows' list so, each row will be extracted and stored in 'row'
                                                writer.writerow(row)  #writerow function will write/add new row in copy_of_College_details.csv.
                                    elif br=='CH':  #if br value 'CH' then
                                        rows = zip(CollegeCode,CSE,IT,ME,EE,EC,IC,branch,ICT,Rank)  #zip combine multiple list into one list so all list combine into 'rows' 
                                        with open('copy_of_College_details.csv','w',newline="\n") as file:  #Open/Create file with 'w' mode.
                                            writer=csv.writer(file, delimiter=',')  #Declaring writer to write data into copy_of_College_details.csv file.
                                            writer.writerow(["CollegeCode", "CSE", "IT", "ME", "EE", "EC", "IC", "CH", "ICT", "Rank"])  #write first row in copy_of_College_details.csv
                                            for row in rows:  #There are multiple rows in 'rows' list so, each row will be extracted and stored in 'row'
                                                writer.writerow(row)  #writerow function will write/add new row in copy_of_College_details.csv.
                                    elif br=='ICT':  #if br value 'ICT' then
                                        rows = zip(CollegeCode,CSE,IT,ME,EE,EC,IC,branch,ICT,Rank)  #zip combine multiple list into one list so all list combine into 'rows' 
                                        with open('copy_of_College_details.csv','w',newline="\n") as file:  #Open/Create file with 'w' mode.
                                            writer=csv.writer(file, delimiter=',')  #Declaring writer to write data into copy_of_College_details.csv file.
                                            writer.writerow(["CollegeCode", "CSE", "IT", "ME", "EE", "EC", "IC", "CH", "ICT", "Rank"])  #write first row in copy_of_College_details.csv
                                            for row in rows:  #There are multiple rows in 'rows' list so, each row will be extracted and stored in 'row'
                                                writer.writerow(row)  #writerow function will write/add new row in copy_of_College_details.csv.
                                else: #if temp1[1] value is not less then or equals to temp1[6] value then
                                    check=0  #set check=0
                        flag=1 #if satisfy all the condition then set flag = 1 so process not execute again

                for x in S_Choice:
                    Enrollment.append(x) #append the 'S_Choice' data into Enrollment list

                #print(Enrollment)


                with open('choice_filling.csv','a',newline="") as file:  #Open/Create file with 'a' mode.
                    writer=csv.writer(file)  #Declaring writer to write data into choice_filling.csv file.
                    writer.writerow(Enrollment)  #writerow function will write/add new row in choice_filling.csv.
                    count += 1  #increment count by 1

                with open('choice_filling.csv') as csv_file:
                    csv_reader = csv.reader(csv_file) #All the data of choice_filling.csv is stored in 'csv_reader'
                    rows = list(csv_reader) #store data in rows list
                    print("\n******** Your Data Are **********")
                    print(rows[1-1]) #print the first row of this 'rows' list
                    print(rows[count])  #print the rows[count] row of this 'rows' list

                Enrollment.clear() #clear the 'Enrollment' list
                S_Choice.clear()  #clear the 'S_Choice' list
                branch1.clear()  #clear the 'branch1' list
                branch2.clear()  #clear the 'branch2' list
            
    def copy_csv(filename): #define function with copy_csv name
        df = pd.read_csv('copy_of_College_details.csv')  #Read data from file 'copy_of_College_details.csv' and store in df
        df.to_csv('day_{}'.format(day) + '_college_status.csv') #give name of the csv file for the data of copy_of_College_details.csv file copy into it
    copy_csv('copy_of_College_details.csv') #call the function
# Out:
# ***** Day 1 *****
# Enter Enrollmentno ::- E00012
#
# Enter the 3 Branch That You want to get Admission ::-
#
# 1) CSE
# 2) IT
# 3) ME
# 4) EE
# 5) EC
# 6) IC
# 7) CH
# 8) ICT
# Enter Branch 1 ::- 4
# Enter Branch 2 ::- 1
# Enter Branch 3 ::- 2
#
# ***********************************
# ********** Your Data **************
# ***********************************
#   CollegeCode  CSE   IT   EE  Rank
# 4       C0005  180  180   60     1
# 7       C0008    0    0  120     2
# 5       C0006  120  180  180     3
# 6       C0007  120  180  120     4
# 3       C0004   60  120    0     5
# 1       C0002    0  180  120     6
# 8       C0009  180    0  120     7
# 2       C0003    0   60    0     8
# 9       C0010   60  180  120     9
# 0       C0001    0   60  120    10
#
# Enter The 10 Choice ::-
# Enter CollegeCode 1 ::- C0009
# Enter Branch 1 ::- EE
# Enter CollegeCode 2 ::- C0007
# Enter Branch 2 ::- IT
# Enter CollegeCode 3 ::- C0006
# Enter Branch 3 ::- EE
# Enter CollegeCode 4 ::- C0008
# ...

# %% [markdown]
# # Question - 5
#
# Q-5 - Generate the report which shows the collegewise-branchwise first and last enrolment number which can be helpful to next         year students. i.e C0001-CE E0001 E0212.
#
# Answer ->
#
#           in this 5 question frist create the CollegeCode_Branch.csv file so easy way to find out the report data
#           like C0001-CE E0001 E0212 and so many data
#           in this question first print the title like 'Clg-Branch', 'First-EnRoll', 'Last-EnRoll' then main logic will
#           be implement in this logic match the CollegeCode_Branch.csv file of the column CollegeCode_Branch in first row
#           with the report.csv file column CollegeCode_Branch each row if it is match then store row of the
#           column EnrollmentNo value into one list this process is execute until last row of the report.csv file then
#           set flag = 1
#           if flag = 1 then list store into report1.csv file the sort report1.csv file in ascending then print the first
#           row of the CollegeCode_Branch column and first row of the report1.csv file and last row of the report1.csv
#           file after print data this list will be clear and take the second row of the CollegeCode_Branch.csv file and
#           repeat this process until the last row of the CollegeCode_Branch.csv file

# %%
#the process shows the data collegewise-branchwise first and last enrolment number
#thats why i am create this process so easy way to find out this report so create the CollegeCode_Branch.csv file
#that contain all the collegecode with its all branches like C0001-CSE,C0001-IT,C0001-ME,C0002-CSE,C0003-IT,etc
with open('CollegeCode_Branch.csv','w',newline="\n") as file:  #Open/Create file with 'w' mode
    writer=csv.writer(file, delimiter=',')  #Declaring writer to write data into CollegeCode_Branch.csv file.
    writer.writerow(["CollegeCode_Branch"])  #write first row in CollegeCode_Branch.csv

CollegeCode=list([])  #This List is used to store the CollegeCode values
clg = 'C'  #variable clg declare with 'C' will be used as combine with CollegeCode  
for i in range(1,11):  #For Loop to insert 10 records from in CollegeCode list
    s = ''.join(['{0:04}'.format(i)])  #in variable s assign 0001,0002 base on i 
    ans = clg+s+"-CSE"  #variable ans combine varible clg and variable s and "-CSE" string
    CollegeCode.append(ans)  #variable ans value append in the CollegeCode list
    
out = open('CollegeCode_Branch.csv', 'a')  #open csv file with 'a' mode
for row in CollegeCode:  #There are multiple data in 'CollegeCode' list so, each data will be extracted and stored in 'row'
    for column in row: 
        out.write(column) #data write in CollegeCode_Branch.csv file with new row
    out.write('\n')
out.close()

CollegeCode.clear()  #clear the 'CollegeCode' list

CollegeCode=list([])  #This List is used to store the CollegeCode values
clg = 'C'  #variable clg declare with 'C' will be used as combine with CollegeCode
for i in range(1,11):  #For Loop to insert 10 records from in CollegeCode list
    s = ''.join(['{0:04}'.format(i)])  #in variable s assign 0001,0002 base on i 
    ans = clg+s+"-IT"  #variable ans combine varible clg and variable s and "-IT" string
    CollegeCode.append(ans)  #variable ans value append in the CollegeCode list
    
out = open('CollegeCode_Branch.csv', 'a') #open csv file with 'a' mode
for row in CollegeCode:
    for column in row:
        out.write(column)  #data write in CollegeCode_Branch.csv file with new row
    out.write('\n')
out.close()

CollegeCode.clear()  #clear the 'CollegeCode' list

CollegeCode=list([])  #This List is used to store the CollegeCode values
clg = 'C'  #variable clg declare with 'C' will be used as combine with CollegeCode
for i in range(1,11): #For Loop to insert 10 records from in CollegeCode list
    s = ''.join(['{0:04}'.format(i)])  #in variable s assign 0001,0002 base on i 
    ans = clg+s+"-ME"  #variable ans combine varible clg and variable s and "-ME" string
    CollegeCode.append(ans)  #variable ans value append in the CollegeCode list
    
out = open('CollegeCode_Branch.csv', 'a')  #open csv file with 'a' mode
for row in CollegeCode:
    for column in row:
        out.write(column)  #data write in CollegeCode_Branch.csv file with new row
    out.write('\n')
out.close()

CollegeCode.clear()  #clear the 'CollegeCode' list

CollegeCode=list([])  #This List is used to store the CollegeCode values
clg = 'C'  #variable clg declare with 'C' will be used as combine with CollegeCode
for i in range(1,11):  #For Loop to insert 10 records from in CollegeCode list
    s = ''.join(['{0:04}'.format(i)])  #in variable s assign 0001,0002 base on i 
    ans = clg+s+"-EE"  #variable ans combine varible clg and variable s and "-EE" string
    CollegeCode.append(ans)  #variable ans value append in the CollegeCode list
    
out = open('CollegeCode_Branch.csv', 'a')  #open csv file with 'a' mode
for row in CollegeCode:
    for column in row:
        out.write(column)  #data write in CollegeCode_Branch.csv file with new row
    out.write('\n')
out.close()

CollegeCode.clear()  #clear the 'CollegeCode' list

CollegeCode=list([])  #This List is used to store the CollegeCode values
clg = 'C'  #variable clg declare with 'C' will be used as combine with CollegeCode
for i in range(1,11):  #For Loop to insert 10 records from in CollegeCode list
    s = ''.join(['{0:04}'.format(i)])  #in variable s assign 0001,0002 base on i 
    ans = clg+s+"-IC"  #variable ans combine varible clg and variable s and "-IC" string
    CollegeCode.append(ans)  #variable ans value append in the CollegeCode list
    
out = open('CollegeCode_Branch.csv', 'a')  #open csv file with 'a' mode
for row in CollegeCode:
    for column in row:
        out.write(column)  #data write in CollegeCode_Branch.csv file with new row
    out.write('\n')
out.close()

CollegeCode.clear()  #clear the 'CollegeCode' list

CollegeCode=list([])  #This List is used to store the CollegeCode values
clg = 'C'  #variable clg declare with 'C' will be used as combine with CollegeCode
for i in range(1,11):  #For Loop to insert 10 records from in CollegeCode list
    s = ''.join(['{0:04}'.format(i)])  #in variable s assign 0001,0002 base on i 
    ans = clg+s+"-CH"  #variable ans combine varible clg and variable s and "-CH" string
    CollegeCode.append(ans)  #variable ans value append in the CollegeCode list
    
out = open('CollegeCode_Branch.csv', 'a')  #open csv file with 'a' mode
for row in CollegeCode:
    for column in row:
        out.write(column)  #data write in CollegeCode_Branch.csv file with new row
    out.write('\n')
out.close()

CollegeCode.clear()  #clear the 'CollegeCode' list

CollegeCode=list([])  #This List is used to store the CollegeCode values
clg = 'C'  #variable clg declare with 'C' will be used as combine with CollegeCode
for i in range(1,11):  #For Loop to insert 10 records from in CollegeCode list
    s = ''.join(['{0:04}'.format(i)])  #in variable s assign 0001,0002 base on i 
    ans = clg+s+"-ICT"  #variable ans combine varible clg and variable s and "-ICT" string
    CollegeCode.append(ans)  #variable ans value append in the CollegeCode list
    
out = open('CollegeCode_Branch.csv', 'a')  #open csv file with 'a' mode
for row in CollegeCode:
    for column in row:
        out.write(column)  #data write in CollegeCode_Branch.csv file with new row
    out.write('\n')
out.close()

# %%
temp = ['Clg-Branch','First-EnRoll','Last-EnRoll']  #declare temp list with given data
print(temp) #print the temp
temp1 = ([])  #This List is used to store the temp1 values
ans = ([])  #This List is used to store the ans values
read1=pd.read_csv("CollegeCode_Branch.csv")  #Read data from file 'CollegeCode_Branch.csv' and store in read1
CollegeCode_Branch=np.array(read1['CollegeCode_Branch'])  #CollegeCode_Branch column is extracted out from 'read1' and stored in 'CollegeCode_Branch' Array
read2=pd.read_csv("report.csv")  #Read data from file 'report.csv' and store in read2
temp = read2.sort_values(by = "CollegeCode_Branch", ascending=True)  #CollegeCode_Branch column store in 'temp' Array in ascending order
CollegeCode_Branch1=np.array(temp['CollegeCode_Branch'])  #CollegeCode_Branch column is extracted out from 'temp' and stored in 'CollegeCode_Branch1'
EnrollmentNo=np.array(temp['EnrollmentNo'])  #EnrollmentNo column is extracted out from 'temp' and stored in 'EnrollmentNo'

for i in range(len(CollegeCode_Branch)):
    flag=0 #set flag = 0
    for j in range(len(CollegeCode_Branch1)):
        if(CollegeCode_Branch[i] == CollegeCode_Branch1[j]): #check CollegeCode_Branch[i] match with CollegeCode_Branch1[j] then
            temp1.append(EnrollmentNo[j]) #append EnrollmentNo[j] into temp1
            flag=1 #set flag=1
    
    if flag == 1: #if flag = 1 then
        out = open('report1.csv', 'w') #open/create report1.csv with 'w' mode
        out.write('sort\n') #write first row in CollegeCode_Branch.csv
        for row in temp1:
            for column in row:
                out.write(column) #data write in report1.csv file with new row
            out.write('\n')
        out.close()
        
        data = pd.read_csv("report1.csv")  #Read data from file 'report1.csv' and store in data
        test = data.sort_values(by = "sort", ascending=True) #sort the 'sort' column in ascending order and store in test
        sort1=np.array(test['sort']) #sort column is extracted out from 'temp' and stored in 'sort1'
        l = len(sort1) #assign length of sort1 array
        m = sort1[0] #assign value of sort1[0]
        n = sort1[l-1] #assign value of sort1[l-1]
        ans.append(CollegeCode_Branch[i])  #append value of CollegeCode_Branch[i] into ans
        ans.append(m)  #append value of m into ans
        ans.append(n)  #append value of n into ans
        print(ans)  #print ans
        temp1.clear() #clear temp1
        ans.clear() #clear ans
# Out:
# ['Clg-Branch', 'First-EnRoll', 'Last-EnRoll']
# ['C0004-CSE', 'E00001', 'E00001']
# ['C0006-CSE', 'E00007', 'E00007']
# ['C0010-CSE', 'E00014', 'E00014']
# ['C0001-IT', 'E00003', 'E00047']
# ['C0002-IT', 'E00008', 'E00008']
# ['C0003-IT', 'E00029', 'E00029']
# ['C0007-IT', 'E00032', 'E00032']
# ['C0002-ME', 'E00038', 'E00038']
# ['C0004-ME', 'E00041', 'E00050']
# ['C0007-ME', 'E00043', 'E00043']
# ['C0008-ME', 'E00016', 'E00016']
# ['C0010-ME', 'E00013', 'E00013']
# ['C0001-EE', 'E00015', 'E00049']
# ['C0002-EE', 'E00035', 'E00035']
# ['C0005-EE', 'E00002', 'E00002']
# ['C0006-EE', 'E00031', 'E00037']
# ['C0009-EE', 'E00012', 'E00012']
# ['C0010-EE', 'E00017', 'E00017']
# ['C0001-IC', 'E00018', 'E00018']
# ['C0002-IC', 'E00042', 'E00042']
# ['C0006-IC', 'E00009', 'E00009']
# ['C0009-IC', 'E00011', 'E00011']
# ['C0002-CH', 'E00046', 'E00046']
# ['C0004-CH', 'E00019', 'E00039']
# ['C0006-CH', 'E00036', 'E00036']
# ['C0008-CH', 'E00004', 'E00004']
# ['C0009-CH', 'E00025', 'E00025']
# ...

# %% [markdown]
# # Question - 6
#
# Q-6 - Also publish rank to each branch which is highly preferred by student for current year admission.
#
# Answer ->
#
#           in this 6 question first create the list declate the list with the all branch name and declare another list
#           with total number of student of each branch that take the admission (the total number of students of each branch
#           value are fetch by the 2 & 3 Question) and each record store in the Rank_Of_Branch.csv file
#
#           in this question read the Rank_Of_Branch.csv file using read_csv() function and then assign rank to the
#           'Total' column in descending order means high value assign 1st rank. then create the 'Rank' column in this
#           column assign rank base on 'Total' column rank in descending order and last sort the all record descending order
#           base on 'Total' column.
#
#           and finally print the Rank_Of_Branch.csv file

# %%
branch = ['CSE', 'IT', 'ME', 'EE', 'EC', 'IC', 'CH', 'ICT']  #declare branch list with given data
total = [t_cse,t_it,t_me,t_ee,t_ec,t_ic,t_ch,t_ict]  #declare total list with given variable value

rows = zip(branch,total)  #zip combine multiple list into one list so all list combine into 'rows'

my_file = Path("Rank_Of_Branch.csv")  #check the Rank_Of_Branch.csv file path are avilable or not
if my_file.is_file():  #check file is exist or not
    os.remove('Rank_Of_Branch.csv')  #if file is exist so remove it

with open('Rank_Of_Branch.csv','w',newline="\n") as file:  #Open/Create file with 'w' mode.
    writer=csv.writer(file, delimiter=',')  #Declaring writer to write data into Rank_Of_Branch.csv file.
    writer.writerow(["Branch","Total"])  #write first row in Rank_Of_Branch.csv.
    for row in rows:  #There are multiple row in 'rows' list so, each row will be extracted and stored in 'row'
        writer.writerow(row)  #writerow function will write/add new row in Rank_Of_Branch.csv.
        
rank_of_branch = pd.read_csv("Rank_Of_Branch.csv")  #Read data from file 'Rank_Of_Branch.csv' and store in rank_of_branch

rank_of_branch["Total"].rank(ascending=False).astype(int)  #give the rank of column 'Total' in descending order
rank_of_branch["Rank"] = rank_of_branch["Total"].rank(ascending=False).astype(int)  #create the column name 'Rank' given the rank base on the column 'Total' in descending order
example = rank_of_branch.sort_values(by = "Total", ascending=False)  #sort the all recode descending order base on column 'Total' 
example  #Preview the loaded data
# Out:
#   Branch  Total  Rank
# 3     EE      8     2
# 4     EC      8     2
# 6     CH      8     2
# 1     IT      7     4
# 2     ME      6     5
# 7    ICT      6     5
# 5     IC      4     7
# 0    CSE      3     8
